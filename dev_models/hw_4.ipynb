# %% [markdown]
# ## Домашнее задание
# ### Основные пункты оценки
# 1. значение метрики на лидерборде
# 2. ревью кода в ноутбуке
# 3. реализация сервиса для модели
#
# Вы можете сделать **НЕ ВСЕ пункты и все равно получить 20 баллов**. Получение > 20 баллов будет расцениваться как 20.
#
# ### Подробности
# #### 1. Побейте метрику на лидерборде map@10 = 0.075 c моделью из implicit, lightfm или rectools, в том числе используя ANN **(5 баллов)**
# #### 2. Реализуйте эксперименты c моделями из implicit, lightfm или rectools, в том числе используя ANN. Результат - ноутбук(и) **(максимум 12 баллов)**
# Что можно сделать в ноутбуке:
# - Реализовать тюнинг гиперпараметров для моделей из implicit, lightfm или rectools **(3 балла)**
#   - Для перебора гиперпараметров можно использовать [`Optuna`](https://github.com/optuna/optuna), [`Hyperopt`](https://github.com/hyperopt/hyperopt)
# - Воспользоваться методом приближенного поиска соседей для выдачи рекомендаций. **(3 балла)**
#     - Можно использовать любые удобные: [`Annoy`](https://github.com/spotify/annoy), [`nmslib`](https://github.com/nmslib/nmslib) и.т.д
# - Сделать рекомендации для холодных пользователей используя их фичи (для кого нет фичей - там другим способом) **(3 балла)**
# - Провести эксперименты с параметрами оффлайн валидации и сделать выводы **(3 балла)**
#
# #### 3. Оберните модель в сервис **(максимум 12 баллов)**
# - Онлайн вариант: обучаете модель в ноутбуке, сохраняете обученную модель (pickle, dill), при запуске сервиса ее поднимаете и запрашиваете рекомендации "на лету" **(12 баллов)**
# - Оффлайн вариант: предварительно посчитайте рекомендации для всех пользователей, сохраните и запрашивайте их **(6 баллов)**

# %%
import os
from copy import deepcopy
from typing import List

from implicit.nearest_neighbours import CosineRecommender, TFIDFRecommender, BM25Recommender
from implicit.als import AlternatingLeastSquares
from implicit.bpr import BayesianPersonalizedRanking
from implicit.lmf import LogisticMatrixFactorization

import pandas as pd

from rectools.dataset import Dataset
from rectools import Columns
from rectools.model_selection import TimeRangeSplitter
from rectools.models import PopularModel, RandomModel, ImplicitALSWrapperModel, LightFMWrapperModel
from rectools.tools.ann import UserToItemAnnRecommender
from rectools.metrics import MAP, NDCG, Precision, Recall, MeanInvUserFreq, Serendipity

from lightfm import LightFM

import warnings

from dev_eval import calculate_metrics, read_kion_dataset, visualize
from userknn import UserKnn

pd.set_option("display.max_columns", None)
warnings.filterwarnings("ignore")
# Out:
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib

# %% [markdown]
# # Data
#
# Подгружаем датасет кион используя дополнительную функцию

# %%
kion_data = read_kion_dataset(fast_check=1)
interactions = kion_data["interactions"]
users = kion_data["users"]
items = kion_data["items"]

# %% [markdown]
# # Гиперпараметры

# %% [markdown]
# Смотреть только на MAP скучно, поэтому давайте смотреть на все метрики, которые брали в прошлый раз, но только для `k_recos=10`, так как все равно рекомендуем 10.

# %%
metrics = {
    "MAP@10": MAP(k=10),
    "NDCG@10": NDCG(k=10),
    "precision@10": Precision(k=10),
    "recall@10": Recall(k=10),
    "novelty@10": MeanInvUserFreq(k=10),
    "serendipity@10": Serendipity(k=10),
}

# %% [markdown]
# Сплиттер:
# * `rectools.model_selection.TimeRangeSplitter`,
# * 3 фолда на кросс-валидации
# * оставим 7 дней (в прошлый раз выяснили, что 7 и 14 работает примерно одинаково)

# %%
cv_7d = TimeRangeSplitter(
    test_size="7D",  # по неделе
    n_splits=3,  # 4 фолда для кросс-валидации
    filter_already_seen=True,  # исключение просмотренных айтемов
    filter_cold_items=True,  # исключение холодных айтемов
    filter_cold_users=True,  #  исключение холодных юзеров
)

# %%
k_recos = 10

# %% [markdown]
# В задании сказано тюнить гиперпараметры, и можно воспользоваться бибилиотеками. Но у нас уже написаны функции для оценки моделей и тд, не хочется их переписывать под бибилиотеки, поэтому просто сделаем маленькую функцию, которая по словарю с параметрами, темплэйту имени модели, а также КлассуМодели возвращает словарь со всевозможными моделями.

# %%
from itertools import product


def is_dict(var):
    return isinstance(var, dict)


def create_models_dict(param_dict: dict, name_template: str, ModelClass):
    # this needed in case value of dict is another dict (e.g. dict of models)
    param_keys_dict = dict()
    param_values_dict = dict()

    for item in param_dict:
        param_keys_dict[item] = param_dict[item]
        param_values_dict[item] = param_dict[item]
        if is_dict(param_dict[item]):
            param_keys_dict[item] = list(param_dict[item].keys())
            param_values_dict[item] = list(param_dict[item].values())

    models_dict = {}

    # Extract keys and values from initial dict of parameters
    keys = list(param_dict.keys())
    values = [param_values_dict[key] for key in keys]
    values_names = [param_keys_dict[key] for key in keys]

    value_combinations = product(*values)
    name_combinations = product(*values_names)

    # Generate all combinations of parameter values
    for value_combination, name_combination in zip(value_combinations, name_combinations):
        param_names = dict(zip(keys, name_combination))
        params = deepcopy(dict(zip(keys, value_combination)))
        model_name = name_template.format(**param_names)
        models_dict[model_name] = ModelClass(**params)

    return models_dict

# %% [markdown]
# # Популярное
#
# Будем использовать популярное (как и в прошлый раз) как бейзлайн, кроме того, его можно потом использовать для добавления к недостающим ответам и к холодным пользователям (с теплыми (про которые есть какая-то информация, мы попробуем сделать кое-что другое)).

# %%
param_set = {"popularity": ["n_users", "n_interactions", "mean_weight"]}
name_template = "popular__{popularity}"
models_popular = create_models_dict(param_set, name_template, PopularModel)
models_popular
# Out:
# {'popular__n_users': <rectools.models.popular.PopularModel at 0x7fad60241220>,
#  'popular__n_interactions': <rectools.models.popular.PopularModel at 0x7fac3637edf0>,
#  'popular__mean_weight': <rectools.models.popular.PopularModel at 0x7fac3637e250>}

# %%
# %%time
result_data = calculate_metrics(models_popular, kion_data, metrics, cv_7d, k_recos=k_recos, style=True, verbose=0)
display(result_data)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# #T_40c79_row0_col0, #T_40c79_row0_col2, #T_40c79_row0_col4, #T_40c79_row0_col6, #T_40c79_row1_col8, #T_40c79_row1_col10, #T_40c79_row2_col8, #T_40c79_row2_col10 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# #T_40c79_row0_col8, #T_40c79_row0_col10, #T_40c79_row1_col0, #T_40c79_row1_col2, #T_40c79_row1_col4, #T_40c79_row1_col6, #T_40c79_row2_col0, #T_40c79_row2_col2, #T_40c79_row2_col4, #T_40c79_row2_col6 {
#   background-color: #398649;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40c79">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_40c79_level0_col0" class="col_heading level0 col0" colspan="2">MAP</th>
#       <th id="T_40c79_level0_col2" class="col_heading level0 col2" colspan="2">NDCG</th>
#       <th id="T_40c79_level0_col4" class="col_heading level0 col4" colspan="2">precision</th>
#       <th id="T_40c79_level0_col6" class="col_heading level0 col6" colspan="2">recall</th>
#       <th id="T_40c79_level0_col8" class="col_heading level0 col8" colspan="2">novelty</th>
#       <th id="T_40c79_level0_col10" class="col_heading level0 col10" colspan="2">serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >At</th>
#       <th id="T_40c79_level1_col0" class="col_heading level1 col0" colspan="2">10</th>
#       <th id="T_40c79_level1_col2" class="col_heading level1 col2" colspan="2">10</th>
#       <th id="T_40c79_level1_col4" class="col_heading level1 col4" colspan="2">10</th>
#       <th id="T_40c79_level1_col6" class="col_heading level1 col6" colspan="2">10</th>
#       <th id="T_40c79_level1_col8" class="col_heading level1 col8" colspan="2">10</th>
#       <th id="T_40c79_level1_col10" class="col_heading level1 col10" colspan="2">10</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Stat</th>
#       <th id="T_40c79_level2_col0" class="col_heading level2 col0" >mean</th>
#       <th id="T_40c79_level2_col1" class="col_heading level2 col1" >std</th>
#       <th id="T_40c79_level2_col2" class="col_heading level2 col2" >mean</th>
#       <th id="T_40c79_level2_col3" class="col_heading level2 col3" >std</th>
#       <th id="T_40c79_level2_col4" class="col_heading level2 col4" >mean</th>
#       <th id="T_40c79_level2_col5" class="col_heading level2 col5" >std</th>
#       <th id="T_40c79_level2_col6" class="col_heading level2 col6" >mean</th>
#       <th id="T_40c79_level2_col7" class="col_heading level2 col7" >std</th>
#       <th id="T_40c79_level2_col8" class="col_heading level2 col8" >mean</th>
#       <th id="T_40c79_level2_col9" class="col_heading level2 col9" >std</th>
#       <th id="T_40c79_level2_col10" class="col_heading level2 col10" >mean</th>
#       <th id="T_40c79_level2_col11" class="col_heading level2 col11" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40c79_level0_row0" class="row_heading level0 row0" >popular__mean_weight</th>
#       <td id="T_40c79_row0_col0" class="data row0 col0" >0.000004</td>
#       <td id="T_40c79_row0_col1" class="data row0 col1" >0.000003</td>
#       <td id="T_40c79_row0_col2" class="data row0 col2" >0.000002</td>
#       <td id="T_40c79_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_40c79_row0_col4" class="data row0 col4" >0.000003</td>
#       <td id="T_40c79_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_40c79_row0_col6" class="data row0 col6" >0.000016</td>
#       <td id="T_40c79_row0_col7" class="data row0 col7" >0.000010</td>
#       <td id="T_40c79_row0_col8" class="data row0 col8" >18.563409</td>
#       <td id="T_40c79_row0_col9" class="data row0 col9" >0.051314</td>
#       <td id="T_40c79_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_40c79_row0_col11" class="data row0 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40c79_level0_row1" class="row_heading level0 row1" >popular__n_interactions</th>
#       <td id="T_40c79_row1_col0" class="data row1 col0" >0.068934</td>
#       <td id="T_40c79_row1_col1" class="data row1 col1" >0.004929</td>
#       <td id="T_40c79_row1_col2" class="data row1 col2" >0.036913</td>
#       <td id="T_40c79_row1_col3" class="data row1 col3" >0.002218</td>
#       <td id="T_40c79_row1_col4" class="data row1 col4" >0.031054</td>
#       <td id="T_40c79_row1_col5" class="data row1 col5" >0.001912</td>
#       <td id="T_40c79_row1_col6" class="data row1 col6" >0.159616</td>
#       <td id="T_40c79_row1_col7" class="data row1 col7" >0.010803</td>
#       <td id="T_40c79_row1_col8" class="data row1 col8" >3.437632</td>
#       <td id="T_40c79_row1_col9" class="data row1 col9" >0.004487</td>
#       <td id="T_40c79_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_40c79_row1_col11" class="data row1 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40c79_level0_row2" class="row_heading level0 row2" >popular__n_users</th>
#       <td id="T_40c79_row2_col0" class="data row2 col0" >0.068934</td>
#       <td id="T_40c79_row2_col1" class="data row2 col1" >0.004929</td>
#       <td id="T_40c79_row2_col2" class="data row2 col2" >0.036913</td>
#       <td id="T_40c79_row2_col3" class="data row2 col3" >0.002218</td>
#       <td id="T_40c79_row2_col4" class="data row2 col4" >0.031054</td>
#       <td id="T_40c79_row2_col5" class="data row2 col5" >0.001912</td>
#       <td id="T_40c79_row2_col6" class="data row2 col6" >0.159616</td>
#       <td id="T_40c79_row2_col7" class="data row2 col7" >0.010803</td>
#       <td id="T_40c79_row2_col8" class="data row2 col8" >3.437632</td>
#       <td id="T_40c79_row2_col9" class="data row2 col9" >0.004487</td>
#       <td id="T_40c79_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_40c79_row2_col11" class="data row2 col11" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 49.1 s, sys: 1.12 s, total: 50.2 s
# Wall time: 50.2 s

# %% [markdown]
# Популярное на взаимодействиях работает одинаково с популярным на пользователях, воспользуемся первым. Но сначала проверим, все ли с ним хорошо.

# %%
item_data = ["title", "genres"]
k_recos = 10
users_list = [
    79446,
    1074610,
]
dataset_for_train = Dataset.construct(interactions.df)

# %%
model_popular = deepcopy(models_popular["popular__n_interactions"])
model_popular.fit(dataset_for_train)

# %%
visualize(
    model=model_popular, dataset=kion_data, user_list=users_list, item_data=item_data, k_recos=20, display=display
)
# Out:
# Visual report
# ----------------------------------------------------------
# User: 79446
# Already watched films amount: 33
# Display last 10 watched:
#     item_id   datetime  weight  watched_pct  item_id_x  \
# 15      512 2021-08-15  3303.0         58.0        512
# 32     1896 2021-08-01  3720.0         57.0       1896
# 19     7597 2021-08-01  5752.0        100.0       7597
# 9     16415 2021-07-28  6847.0        100.0      16415
# 7      4880 2021-07-25  2634.0          9.0       4880
# 14    12356 2021-07-18  4071.0         77.0      12356
# 30     9194 2021-07-17  6760.0         95.0       9194
# 18     9728 2021-07-17    52.0          1.0       9728
# 5     10240 2021-07-16  6126.0        100.0      10240
# 25    10464 2021-07-13     8.0          0.0      10464
#
#                         title                        genres  item_id_y
# 15             Рядовой Чээрин                       военные      10230
# 32                    Явление                драмы, военные        674
# 19    Препод: История Галатеи     драмы, триллеры, криминал       1717
# 9                       Весна  фантастика, ужасы, мелодрамы        624
# 7                       Афера                       комедии      55043
# 14                  13 грехов               ужасы, триллеры       6874
# 30  Роберт — король Шотландии                       боевики       8030
# 18          Гнев человеческий             боевики, триллеры     132865
# 5                Клаустрофобы                      триллеры       4336
# 25               Вирус страха               драмы, триллеры      10375
# Recommended films amount: 20
# (Amount of all films: 15706)
# Display first 10 recommendations:
#    item_id     score  rank  item_id_x                         title  \
# 0    10440  202457.0     1      10440                   Хрустальный
# 1    15297  193123.0     2      15297               Клиника счастья
# 2     4151   91167.0     3       4151        Секреты семейной жизни
# 3     3734   74803.0     4       3734  Прабабушка легкого поведения
# 4     2657   68581.0     5       2657                    Подслушано
# 5      142   45367.0     6        142                          Маша
# 6     6809   40372.0     7       6809                         Дуров
# 7    12192   38242.0     8      12192                  Фемида видит
# 8     8636   35631.0     9       8636                    Белый снег
# 9     4740   34325.0    10       4740            Сахаров. Две жизни
#
#                       genres  item_id_y
# 0        триллеры, детективы     202457
# 1           драмы, мелодрамы     193123
# 2                    комедии      91167
# 3                    комедии      74803
# 4            драмы, триллеры      68581
# 5            драмы, триллеры      45367
# 6             документальное      40372
# 7  драмы, детективы, комедии      38242
# 8               драмы, спорт      35631
# 9             документальное      34325
# ----------------------------------------------------------
# User: 1074610
# Already watched films amount: 1
# Display last 10 watched:
#    item_id   datetime  weight  watched_pct  item_id_x            title  \
# 0    15297 2021-07-28  1402.0         13.0      15297  Клиника счастья
#
#              genres  item_id_y
# 0  драмы, мелодрамы     193123
# Recommended films amount: 20
# (Amount of all films: 15706)
# Display first 10 recommendations:
#    item_id     score  rank  item_id_x                         title  \
# 0    10440  202457.0     1      10440                   Хрустальный
# 1     9728  132865.0     2       9728             Гнев человеческий
# 2    13865  122119.0     3      13865                      Девятаев
# 3     4151   91167.0     4       4151        Секреты семейной жизни
# 4     3734   74803.0     5       3734  Прабабушка легкого поведения
# 5     2657   68581.0     6       2657                    Подслушано
# 6     4880   55043.0     7       4880                         Афера
# 7      142   45367.0     8        142                          Маша
# 8     6809   40372.0     9       6809                         Дуров
# 9    12192   38242.0    10      12192                  Фемида видит
#
#                         genres  item_id_y
# 0          триллеры, детективы     202457
# 1            боевики, триллеры     132865
# 2  драмы, военные, приключения     122119
# 3                      комедии      91167
# 4                      комедии      74803
# 5              драмы, триллеры      68581
# 6                      комедии      55043
# 7              драмы, триллеры      45367
# 8               документальное      40372
# 9    драмы, детективы, комедии      38242

# %% [markdown]
# # Модели с пары

# %% [markdown]
# ### Подготовка датасета
#
# Переведем юзер и айтем фичи в вид, пригодный ректулсу (как делали на паре, только запихнем код в функции, и обощим функцию для айтемов (чтобы можно было пихать любой список, а не только жанр и контент_тайп)).

# %%
def get_user_features(users: pd.DataFrame, interactions: pd.DataFrame, features: List[str]):
    users.fillna("UnknowЪn", inplace=True)
    users = users.loc[users[Columns.User].isin(interactions[Columns.User])].copy()
    user_features_frames = []
    for feature in features:
        feature_frame = users.reindex(columns=[Columns.User, feature])
        feature_frame.columns = ["id", "value"]
        feature_frame["feature"] = feature
        user_features_frames.append(feature_frame)
    return pd.concat(user_features_frames)


def get_item_features(items: pd.DataFrame, interactions: pd.DataFrame, features: List[str]):
    items = items.loc[items[Columns.Item].isin(interactions[Columns.Item])].copy()
    # разъединяем фичи, которые через запутую ()
    feature_list = []
    for feature in features:
        items[feature] = items[feature].str.lower().str.replace(", ", ",", regex=False).str.split(",")
        cur_feature_df = items[["item_id", feature]].explode(feature)
        cur_feature_df.columns = ["id", "value"]
        cur_feature_df["feature"] = feature
        feature_list.append(cur_feature_df)
    return pd.concat(feature_list)

# %% [markdown]
# #### Юзеры

# %%
user_feature_names = ["sex", "age", "income"]
user_features = get_user_features(deepcopy(users), interactions.df, user_feature_names)
print("До:")
display(users)
print("После:")
display(user_features)
# Out:
# До:
#         user_id         age        income  sex  kids_flg
# 0        973171   age_25_34  income_60_90    М         1
# 1        962099   age_18_24  income_20_40    М         0
# 2       1047345   age_45_54  income_40_60    Ж         0
# 3        721985   age_45_54  income_20_40    Ж         0
# 4        704055   age_35_44  income_60_90    Ж         0
# ...         ...         ...           ...  ...       ...
# 840192   339025  age_65_inf   income_0_20    Ж         0
# 840193   983617   age_18_24  income_20_40    Ж         1
# 840194   251008         NaN           NaN  NaN         0
# 840195   590706         NaN           NaN    Ж         0
# 840196   166555  age_65_inf  income_20_40    Ж         0
#
# [840197 rows x 5 columns]
# После:
#              id         value feature
# 0        973171             М     sex
# 1        962099             М     sex
# 3        721985             Ж     sex
# 4        704055             Ж     sex
# 5       1037719             М     sex
# ...         ...           ...     ...
# 840189   191349  income_40_60  income
# 840190   393868  income_20_40  income
# 840192   339025   income_0_20  income
# 840194   251008      UnknowЪn  income
# 840195   590706      UnknowЪn  income
#
# [2232864 rows x 3 columns]

# %% [markdown]
# #### Айтемы:

# %% [markdown]
# Кроме жанров и фильм/сериал, добавлю еще в рассмотрение страну - так как кажется, что этот фактор тоже важен при выборе фильма, и не сильно раздувает датасет (так как в основном одна-две страны на фильм)).

# %%
item_feature_names = ["content_type", "genres", "countries"]
item_features = get_item_features(deepcopy(items), interactions.df, item_feature_names)
print("До:")
display(items.head())
print("После:")
display(item_features)
# Out:
# До:
#    item_id content_type                 title      title_orig  release_year  \
# 0    10711         film        Поговори с ней  Hable con ella        2002.0
# 1     2508         film           Голые перцы    Search Party        2014.0
# 2    10716         film      Тактическая сила  Tactical Force        2011.0
# 3     7868         film                45 лет        45 Years        2015.0
# 4    16268         film  Все решает мгновение             NaN        1978.0
#
#                                              genres       countries  for_kids  \
# 0           драмы, зарубежные, детективы, мелодрамы         Испания       NaN
# 1                  зарубежные, приключения, комедии             США       NaN
# 2  криминал, зарубежные, триллеры, боевики, комедии          Канада       NaN
# 3                      драмы, зарубежные, мелодрамы  Великобритания       NaN
# 4                драмы, спорт, советские, мелодрамы            СССР       NaN
#
#    age_rating   studios         directors  \
# 0        16.0       NaN  Педро Альмодовар
# 1        16.0       NaN    Скот Армстронг
# 2        16.0       NaN  Адам П. Калтраро
# 3        16.0       NaN         Эндрю Хэй
# 4        12.0  Ленфильм  Виктор Садовский
#
#                                               actors  \
# 0  Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1  Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2  Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
# 3  Александра Риддлстон-Барретт, Джеральдин Джейм...
# 4  Александр Абдулов, Александр Демьяненко, Алекс...
#
#                                          description  \
# 0  Мелодрама легендарного Педро Альмодовара «Пого...
# 1  Уморительная современная комедия на популярную...
# 2  Профессиональный рестлер Стив Остин («Все или ...
# 3  Шарлотта Рэмплинг, Том Кортни, Джеральдин Джей...
# 4  Расчетливая чаровница из советского кинохита «...
#
#                                             keywords
# 0  Поговори, ней, 2002, Испания, друзья, любовь, ...
# 1  Голые, перцы, 2014, США, друзья, свадьбы, прео...
# 2  Тактическая, сила, 2011, Канада, бандиты, ганг...
# 3  45, лет, 2015, Великобритания, брак, жизнь, лю...
# 4  Все, решает, мгновение, 1978, СССР, сильные, ж...
# После:
#           id     value       feature
# 0      10711      film  content_type
# 1       2508      film  content_type
# 2      10716      film  content_type
# 3       7868      film  content_type
# 4      16268      film  content_type
# ...      ...       ...           ...
# 15958   6443  германия     countries
# 15959   2367    россия     countries
# 15960  10632    россия     countries
# 15961   4538    россия     countries
# 15962   3206    россия     countries
#
# [73686 rows x 3 columns]

# %% [markdown]
# #### Конструируем финальный датасет

# %%
dataset = Dataset.construct(
    interactions_df=interactions.df,
    user_features_df=user_features,
    cat_user_features=user_feature_names,
    item_features_df=item_features,
    cat_item_features=item_feature_names,
)

# %% [markdown]
# # Модели
#
# Будем перебирать:
# * ImpliciALSWrapperModel
#     * `fit_features_together=is_fitting_features`
#     * ALS
#         * `factors=N_FACTORS`,
#         * `random_state=RANDOM_STATE`,
#         * `num_threads=NUM_THREADS`,
# * LightFMWrapperModel
#     * `epochs=N_EPOCHS,`
#     * `num_threads=NUM_THREADS,`
#     * LightFM
#         * `no_components=N_FACTORS,`
#         * `loss=LOSS,`
#         * `learning_rate=LEARNING_RATE,`
#         * `user_alpha=USER_ALPHA,`
#         * `item_alpha=ITEM_ALPHA,`
#         * `random_state=RANDOM_STATE,`
#
# Не смог все перебрать в одном цикле, так как почему-то иногда ноутбук просто переставал считать, хотя как будто-бы чт-то считал, и стопился, пришлось разбить на 3 куска:
# * ALS,
# * LFM(N_FACTORS=16),
# * LFM(N_FACTORS=32).

# %%
K_RECOS = 10
RANDOM_STATE = [
    566,
]
NUM_THREADS = [
    16,
]
N_FACTORS = [16, 32]
IS_FITTING_FEATURES = [True, False]
LOSS = ["bpr", "warp"]
N_EPOCHS = [
    2,
]
USER_ALPHA = [0.2, 0.5]
ITEM_ALPHA = [0.2, 0.5]
LEARNING_RATE = [0.01, 0.05]

# %%
# create als for als wrapper
param_set_als = {"factors": N_FACTORS, "random_state": RANDOM_STATE, "num_threads": NUM_THREADS}
als_template = "{factors}"
models_als = create_models_dict(param_set_als, als_template, AlternatingLeastSquares)
# create_wrapper
param_set_als = {"fit_features_together": IS_FITTING_FEATURES, "model": models_als}
als_template = "als__{fit_features_together}_{model}"
models_als_wrapper = create_models_dict(param_set_als, als_template, ImplicitALSWrapperModel)
models_als_wrapper
# Out:
# {'als__True_16': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7fac33c23ee0>,
#  'als__True_32': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7fac33c23c10>,
#  'als__False_16': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7fac33c23880>,
#  'als__False_32': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7fac33c23d60>}

# %%
models_lfm_wrapper_list = []

for N in N_FACTORS:
    # create als for als wrapper
    param_set_lfm = {
        "no_components": [
            N,
        ],
        "loss": LOSS,
        "learning_rate": LEARNING_RATE,
        "user_alpha": USER_ALPHA,
        "item_alpha": ITEM_ALPHA,
        "random_state": RANDOM_STATE,
    }
    lfm_template = "{no_components}_{loss}_{learning_rate}_{user_alpha}_{item_alpha}"
    models_lfm = create_models_dict(param_set_lfm, lfm_template, LightFM)
    # create_wrapper
    param_set_lfm = {"epochs": N_EPOCHS, "num_threads": NUM_THREADS, "model": models_lfm}
    lfm_template = "lfm__{model}"
    models_lfm_wrapper = create_models_dict(param_set_lfm, lfm_template, LightFMWrapperModel)

    models_lfm_wrapper_list.append(models_lfm_wrapper)

models_lfm_wrapper_list
# Out:
# [{'lfm__16_bpr_0.01_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac349b8a00>,
#   'lfm__16_bpr_0.01_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac349b88b0>,
#   'lfm__16_bpr_0.01_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac349d9610>,
#   'lfm__16_bpr_0.01_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02490>,
#   'lfm__16_bpr_0.05_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c024f0>,
#   'lfm__16_bpr_0.05_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c026a0>,
#   'lfm__16_bpr_0.05_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c027f0>,
#   'lfm__16_bpr_0.05_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c029a0>,
#   'lfm__16_warp_0.01_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02b20>,
#   'lfm__16_warp_0.01_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02190>,
#   'lfm__16_warp_0.01_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a34190>,
#   'lfm__16_warp_0.01_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a342e0>,
#   'lfm__16_warp_0.05_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a34430>,
#   'lfm__16_warp_0.05_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a34580>,
#   'lfm__16_warp_0.05_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a346d0>,
#   'lfm__16_warp_0.05_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a34820>},
#  {'lfm__32_bpr_0.01_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02100>,
#   'lfm__32_bpr_0.01_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02040>,
#   'lfm__32_bpr_0.01_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02a30>,
#   'lfm__32_bpr_0.01_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02be0>,
#   'lfm__32_bpr_0.05_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02bb0>,
#   'lfm__32_bpr_0.05_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33e77a30>,
#   'lfm__32_bpr_0.05_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac349e0220>,
#   'lfm__32_bpr_0.05_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac349b80a0>,
#   'lfm__32_warp_0.01_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33c02160>,
#   'lfm__32_warp_0.01_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38580>,
#   'lfm__32_warp_0.01_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a386d0>,
#   'lfm__32_warp_0.01_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38820>,
#   'lfm__32_warp_0.05_0.2_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38970>,
#   'lfm__32_warp_0.05_0.2_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38ac0>,
#   'lfm__32_warp_0.05_0.5_0.2': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38c10>,
#   'lfm__32_warp_0.05_0.5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7fac33a38d60>}]

# %%
# %%time
result_data_als = calculate_metrics(
    models_als_wrapper, kion_data, metrics, cv_7d, k_recos=k_recos, style=True, verbose=1
)
display(result_data_als)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# =======================================================|| Model: als__True_16 | Fold: 0=======================================================
# Fit time: 57.28 sec.
# Recommend time: 6.55 sec.
# Metrics time: 1.59 sec.
# =======================================================|| Model: als__True_32 | Fold: 0=======================================================
# Fit time: 75.73 sec.
# Recommend time: 6.59 sec.
# Metrics time: 1.57 sec.
# =======================================================|| Model: als__False_16 | Fold: 0=======================================================
# Fit time: 56.76 sec.
# Recommend time: 6.36 sec.
# Metrics time: 1.59 sec.
# =======================================================|| Model: als__False_32 | Fold: 0=======================================================
# Fit time: 77.13 sec.
# Recommend time: 6.48 sec.
# Metrics time: 1.66 sec.
# =======================================================|| Model: als__True_16 | Fold: 1=======================================================
# Fit time: 59.92 sec.
# Recommend time: 6.6 sec.
# Metrics time: 1.77 sec.
# =======================================================|| Model: als__True_32 | Fold: 1=======================================================
# Fit time: 81.44 sec.
# Recommend time: 6.91 sec.
# Metrics time: 1.76 sec.
# =======================================================|| Model: als__False_16 | Fold: 1=======================================================
# Fit time: 59.75 sec.
# Recommend time: 8.85 sec.
# Metrics time: 1.88 sec.
# =======================================================|| Model: als__False_32 | Fold: 1=======================================================
# Fit time: 90.02 sec.
# Recommend time: 7.0 sec.
# Metrics time: 1.75 sec.
# =======================================================|| Model: als__True_16 | Fold: 2=======================================================
# Fit time: 63.82 sec.
# Recommend time: 7.08 sec.
# Metrics time: 1.91 sec.
# =======================================================|| Model: als__True_32 | Fold: 2=======================================================
# Fit time: 87.67 sec.
# Recommend time: 7.45 sec.
# Metrics time: 1.96 sec.
# =======================================================|| Model: als__False_16 | Fold: 2=======================================================
# Fit time: 62.98 sec.
# Recommend time: 6.99 sec.
# Metrics time: 1.89 sec.
# =======================================================|| Model: als__False_32 | Fold: 2=======================================================
# Fit time: 87.1 sec.
# Recommend time: 7.35 sec.
# Metrics time: 1.93 sec.
# <style type="text/css">
# #T_429c0_row0_col0, #T_429c0_row0_col2, #T_429c0_row0_col4, #T_429c0_row0_col6, #T_429c0_row1_col10, #T_429c0_row2_col8 {
#   background-color: #398649;
#   color: #f1f1f1;
# }
# #T_429c0_row0_col8 {
#   background-color: #eecdcf;
#   color: #000000;
# }
# #T_429c0_row0_col10, #T_429c0_row1_col8, #T_429c0_row3_col0, #T_429c0_row3_col2, #T_429c0_row3_col4, #T_429c0_row3_col6 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# #T_429c0_row1_col0 {
#   background-color: #dd505a;
#   color: #f1f1f1;
# }
# #T_429c0_row1_col2, #T_429c0_row1_col4 {
#   background-color: #dd515c;
#   color: #f1f1f1;
# }
# #T_429c0_row1_col6 {
#   background-color: #db404c;
#   color: #f1f1f1;
# }
# #T_429c0_row2_col0 {
#   background-color: #deeae1;
#   color: #000000;
# }
# #T_429c0_row2_col2 {
#   background-color: #c2d9c7;
#   color: #000000;
# }
# #T_429c0_row2_col4, #T_429c0_row2_col6 {
#   background-color: #8fba98;
#   color: #000000;
# }
# #T_429c0_row2_col10 {
#   background-color: #dd4f59;
#   color: #f1f1f1;
# }
# #T_429c0_row3_col8 {
#   background-color: #e38289;
#   color: #f1f1f1;
# }
# #T_429c0_row3_col10 {
#   background-color: #aacbb1;
#   color: #000000;
# }
# </style>
# <table id="T_429c0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_429c0_level0_col0" class="col_heading level0 col0" colspan="2">MAP</th>
#       <th id="T_429c0_level0_col2" class="col_heading level0 col2" colspan="2">NDCG</th>
#       <th id="T_429c0_level0_col4" class="col_heading level0 col4" colspan="2">precision</th>
#       <th id="T_429c0_level0_col6" class="col_heading level0 col6" colspan="2">recall</th>
#       <th id="T_429c0_level0_col8" class="col_heading level0 col8" colspan="2">novelty</th>
#       <th id="T_429c0_level0_col10" class="col_heading level0 col10" colspan="2">serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >At</th>
#       <th id="T_429c0_level1_col0" class="col_heading level1 col0" colspan="2">10</th>
#       <th id="T_429c0_level1_col2" class="col_heading level1 col2" colspan="2">10</th>
#       <th id="T_429c0_level1_col4" class="col_heading level1 col4" colspan="2">10</th>
#       <th id="T_429c0_level1_col6" class="col_heading level1 col6" colspan="2">10</th>
#       <th id="T_429c0_level1_col8" class="col_heading level1 col8" colspan="2">10</th>
#       <th id="T_429c0_level1_col10" class="col_heading level1 col10" colspan="2">10</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Stat</th>
#       <th id="T_429c0_level2_col0" class="col_heading level2 col0" >mean</th>
#       <th id="T_429c0_level2_col1" class="col_heading level2 col1" >std</th>
#       <th id="T_429c0_level2_col2" class="col_heading level2 col2" >mean</th>
#       <th id="T_429c0_level2_col3" class="col_heading level2 col3" >std</th>
#       <th id="T_429c0_level2_col4" class="col_heading level2 col4" >mean</th>
#       <th id="T_429c0_level2_col5" class="col_heading level2 col5" >std</th>
#       <th id="T_429c0_level2_col6" class="col_heading level2 col6" >mean</th>
#       <th id="T_429c0_level2_col7" class="col_heading level2 col7" >std</th>
#       <th id="T_429c0_level2_col8" class="col_heading level2 col8" >mean</th>
#       <th id="T_429c0_level2_col9" class="col_heading level2 col9" >std</th>
#       <th id="T_429c0_level2_col10" class="col_heading level2 col10" >mean</th>
#       <th id="T_429c0_level2_col11" class="col_heading level2 col11" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_429c0_level0_row0" class="row_heading level0 row0" >als__False_16</th>
#       <td id="T_429c0_row0_col0" class="data row0 col0" >0.020101</td>
#       <td id="T_429c0_row0_col1" class="data row0 col1" >0.003492</td>
#       <td id="T_429c0_row0_col2" class="data row0 col2" >0.011868</td>
#       <td id="T_429c0_row0_col3" class="data row0 col3" >0.001573</td>
#       <td id="T_429c0_row0_col4" class="data row0 col4" >0.010582</td>
#       <td id="T_429c0_row0_col5" class="data row0 col5" >0.001249</td>
#       <td id="T_429c0_row0_col6" class="data row0 col6" >0.052433</td>
#       <td id="T_429c0_row0_col7" class="data row0 col7" >0.007133</td>
#       <td id="T_429c0_row0_col8" class="data row0 col8" >7.076943</td>
#       <td id="T_429c0_row0_col9" class="data row0 col9" >0.119850</td>
#       <td id="T_429c0_row0_col10" class="data row0 col10" >0.000045</td>
#       <td id="T_429c0_row0_col11" class="data row0 col11" >0.000003</td>
#     </tr>
#     <tr>
#       <th id="T_429c0_level0_row1" class="row_heading level0 row1" >als__False_32</th>
#       <td id="T_429c0_row1_col0" class="data row1 col0" >0.014181</td>
#       <td id="T_429c0_row1_col1" class="data row1 col1" >0.000521</td>
#       <td id="T_429c0_row1_col2" class="data row1 col2" >0.009651</td>
#       <td id="T_429c0_row1_col3" class="data row1 col3" >0.000309</td>
#       <td id="T_429c0_row1_col4" class="data row1 col4" >0.009292</td>
#       <td id="T_429c0_row1_col5" class="data row1 col5" >0.000248</td>
#       <td id="T_429c0_row1_col6" class="data row1 col6" >0.043870</td>
#       <td id="T_429c0_row1_col7" class="data row1 col7" >0.001142</td>
#       <td id="T_429c0_row1_col8" class="data row1 col8" >7.051224</td>
#       <td id="T_429c0_row1_col9" class="data row1 col9" >0.026456</td>
#       <td id="T_429c0_row1_col10" class="data row1 col10" >0.000051</td>
#       <td id="T_429c0_row1_col11" class="data row1 col11" >0.000002</td>
#     </tr>
#     <tr>
#       <th id="T_429c0_level0_row2" class="row_heading level0 row2" >als__True_16</th>
#       <td id="T_429c0_row2_col0" class="data row2 col0" >0.017212</td>
#       <td id="T_429c0_row2_col1" class="data row2 col1" >0.002547</td>
#       <td id="T_429c0_row2_col2" class="data row2 col2" >0.010960</td>
#       <td id="T_429c0_row2_col3" class="data row2 col3" >0.001315</td>
#       <td id="T_429c0_row2_col4" class="data row2 col4" >0.010253</td>
#       <td id="T_429c0_row2_col5" class="data row2 col5" >0.001216</td>
#       <td id="T_429c0_row2_col6" class="data row2 col6" >0.050336</td>
#       <td id="T_429c0_row2_col7" class="data row2 col7" >0.007585</td>
#       <td id="T_429c0_row2_col8" class="data row2 col8" >7.115717</td>
#       <td id="T_429c0_row2_col9" class="data row2 col9" >0.013101</td>
#       <td id="T_429c0_row2_col10" class="data row2 col10" >0.000046</td>
#       <td id="T_429c0_row2_col11" class="data row2 col11" >0.000002</td>
#     </tr>
#     <tr>
#       <th id="T_429c0_level0_row3" class="row_heading level0 row3" >als__True_32</th>
#       <td id="T_429c0_row3_col0" class="data row3 col0" >0.013792</td>
#       <td id="T_429c0_row3_col1" class="data row3 col1" >0.000688</td>
#       <td id="T_429c0_row3_col2" class="data row3 col2" >0.009495</td>
#       <td id="T_429c0_row3_col3" class="data row3 col3" >0.000283</td>
#       <td id="T_429c0_row3_col4" class="data row3 col4" >0.009203</td>
#       <td id="T_429c0_row3_col5" class="data row3 col5" >0.000199</td>
#       <td id="T_429c0_row3_col6" class="data row3 col6" >0.043711</td>
#       <td id="T_429c0_row3_col7" class="data row3 col7" >0.001701</td>
#       <td id="T_429c0_row3_col8" class="data row3 col8" >7.063886</td>
#       <td id="T_429c0_row3_col9" class="data row3 col9" >0.027845</td>
#       <td id="T_429c0_row3_col10" class="data row3 col10" >0.000049</td>
#       <td id="T_429c0_row3_col11" class="data row3 col11" >0.000002</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 1h 34min 44s, sys: 2h 27min 3s, total: 4h 1min 47s
# Wall time: 16min 7s

# %%
# %%time
result_data_lfm0 = calculate_metrics(
    models_lfm_wrapper_list[0], kion_data, metrics, cv_7d, k_recos=k_recos, style=True, verbose=1
)
display(result_data_lfm0)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.2 | Fold: 0=======================================================
# Fit time: 3.2 sec.
# Recommend time: 6.89 sec.
# Metrics time: 1.88 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.5 | Fold: 0=======================================================
# Fit time: 5.84 sec.
# Recommend time: 6.73 sec.
# Metrics time: 1.85 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.2 | Fold: 0=======================================================
# Fit time: 6.52 sec.
# Recommend time: 6.44 sec.
# Metrics time: 1.57 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.5 | Fold: 0=======================================================
# Fit time: 6.46 sec.
# Recommend time: 6.72 sec.
# Metrics time: 1.89 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.2 | Fold: 0=======================================================
# Fit time: 14.67 sec.
# Recommend time: 6.95 sec.
# Metrics time: 1.81 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.5 | Fold: 0=======================================================
# Fit time: 38.84 sec.
# Recommend time: 7.93 sec.
# Metrics time: 1.81 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.2 | Fold: 0=======================================================
# Fit time: 39.04 sec.
# Recommend time: 7.7 sec.
# Metrics time: 1.7 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.5 | Fold: 0=======================================================
# Fit time: 37.53 sec.
# Recommend time: 6.98 sec.
# Metrics time: 1.98 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.2 | Fold: 0=======================================================
# Fit time: 2.89 sec.
# Recommend time: 7.13 sec.
# Metrics time: 1.8 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.5 | Fold: 0=======================================================
# Fit time: 8.27 sec.
# Recommend time: 7.46 sec.
# Metrics time: 1.76 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.2 | Fold: 0=======================================================
# Fit time: 10.3 sec.
# Recommend time: 6.83 sec.
# Metrics time: 1.73 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.5 | Fold: 0=======================================================
# Fit time: 7.59 sec.
# Recommend time: 6.65 sec.
# Metrics time: 1.69 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.2 | Fold: 0=======================================================
# Fit time: 16.05 sec.
# Recommend time: 6.96 sec.
# Metrics time: 1.71 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.5 | Fold: 0=======================================================
# Fit time: 49.74 sec.
# Recommend time: 7.79 sec.
# Metrics time: 1.63 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.2 | Fold: 0=======================================================
# Fit time: 55.71 sec.
# Recommend time: 7.57 sec.
# Metrics time: 1.7 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.5 | Fold: 0=======================================================
# Fit time: 50.49 sec.
# Recommend time: 8.41 sec.
# Metrics time: 1.84 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.2 | Fold: 1=======================================================
# Fit time: 4.34 sec.
# Recommend time: 7.88 sec.
# Metrics time: 2.01 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.5 | Fold: 1=======================================================
# Fit time: 7.11 sec.
# Recommend time: 8.75 sec.
# Metrics time: 2.01 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.2 | Fold: 1=======================================================
# Fit time: 7.83 sec.
# Recommend time: 7.38 sec.
# Metrics time: 1.96 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.5 | Fold: 1=======================================================
# Fit time: 7.57 sec.
# Recommend time: 8.03 sec.
# Metrics time: 1.83 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.2 | Fold: 1=======================================================
# Fit time: 16.6 sec.
# Recommend time: 8.93 sec.
# Metrics time: 1.94 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.5 | Fold: 1=======================================================
# Fit time: 45.04 sec.
# Recommend time: 8.78 sec.
# Metrics time: 1.9 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.2 | Fold: 1=======================================================
# Fit time: 47.36 sec.
# Recommend time: 7.09 sec.
# Metrics time: 1.96 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.5 | Fold: 1=======================================================
# Fit time: 46.16 sec.
# Recommend time: 8.2 sec.
# Metrics time: 1.91 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.2 | Fold: 1=======================================================
# Fit time: 3.28 sec.
# Recommend time: 7.59 sec.
# Metrics time: 1.84 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.5 | Fold: 1=======================================================
# Fit time: 10.33 sec.
# Recommend time: 8.07 sec.
# Metrics time: 1.87 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.2 | Fold: 1=======================================================
# Fit time: 12.16 sec.
# Recommend time: 7.56 sec.
# Metrics time: 1.85 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.5 | Fold: 1=======================================================
# Fit time: 8.53 sec.
# Recommend time: 8.32 sec.
# Metrics time: 2.18 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.2 | Fold: 1=======================================================
# Fit time: 19.68 sec.
# Recommend time: 7.95 sec.
# Metrics time: 2.02 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.5 | Fold: 1=======================================================
# Fit time: 62.45 sec.
# Recommend time: 8.71 sec.
# Metrics time: 2.14 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.2 | Fold: 1=======================================================
# Fit time: 70.56 sec.
# Recommend time: 8.38 sec.
# Metrics time: 2.06 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.5 | Fold: 1=======================================================
# Fit time: 64.85 sec.
# Recommend time: 9.33 sec.
# Metrics time: 2.08 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.2 | Fold: 2=======================================================
# Fit time: 4.76 sec.
# Recommend time: 8.56 sec.
# Metrics time: 2.19 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.2_0.5 | Fold: 2=======================================================
# Fit time: 9.22 sec.
# Recommend time: 8.54 sec.
# Metrics time: 2.31 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.2 | Fold: 2=======================================================
# Fit time: 8.43 sec.
# Recommend time: 7.41 sec.
# Metrics time: 2.01 sec.
# =======================================================|| Model: lfm__16_bpr_0.01_0.5_0.5 | Fold: 2=======================================================
# Fit time: 9.08 sec.
# Recommend time: 8.82 sec.
# Metrics time: 1.98 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.2 | Fold: 2=======================================================
# Fit time: 17.84 sec.
# Recommend time: 7.48 sec.
# Metrics time: 2.16 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.2_0.5 | Fold: 2=======================================================
# Fit time: 49.58 sec.
# Recommend time: 9.16 sec.
# Metrics time: 2.26 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.2 | Fold: 2=======================================================
# Fit time: 59.96 sec.
# Recommend time: 8.99 sec.
# Metrics time: 2.28 sec.
# =======================================================|| Model: lfm__16_bpr_0.05_0.5_0.5 | Fold: 2=======================================================
# Fit time: 57.87 sec.
# Recommend time: 9.13 sec.
# Metrics time: 2.15 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.2 | Fold: 2=======================================================
# Fit time: 4.41 sec.
# Recommend time: 9.16 sec.
# Metrics time: 2.19 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.2_0.5 | Fold: 2=======================================================
# Fit time: 12.49 sec.
# Recommend time: 9.0 sec.
# Metrics time: 2.26 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.2 | Fold: 2=======================================================
# Fit time: 14.68 sec.
# Recommend time: 8.79 sec.
# Metrics time: 2.08 sec.
# =======================================================|| Model: lfm__16_warp_0.01_0.5_0.5 | Fold: 2=======================================================
# Fit time: 11.0 sec.
# Recommend time: 8.26 sec.
# Metrics time: 2.25 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.2 | Fold: 2=======================================================
# Fit time: 22.63 sec.
# Recommend time: 8.51 sec.
# Metrics time: 1.92 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.2_0.5 | Fold: 2=======================================================
# Fit time: 72.68 sec.
# Recommend time: 9.05 sec.
# Metrics time: 2.01 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.2 | Fold: 2=======================================================
# Fit time: 80.44 sec.
# Recommend time: 8.93 sec.
# Metrics time: 2.06 sec.
# =======================================================|| Model: lfm__16_warp_0.05_0.5_0.5 | Fold: 2=======================================================
# Fit time: 69.06 sec.
# Recommend time: 8.49 sec.
# Metrics time: 2.08 sec.
# <style type="text/css">
# #T_0a724_row0_col0, #T_0a724_row0_col2, #T_0a724_row0_col4, #T_0a724_row0_col6, #T_0a724_row0_col10, #T_0a724_row1_col0, #T_0a724_row1_col2, #T_0a724_row1_col4, #T_0a724_row1_col6, #T_0a724_row2_col0, #T_0a724_row2_col2, #T_0a724_row2_col4, #T_0a724_row2_col6, #T_0a724_row3_col0, #T_0a724_row4_col0, #T_0a724_row4_col2, #T_0a724_row4_col4, #T_0a724_row4_col6, #T_0a724_row6_col0, #T_0a724_row7_col0, #T_0a724_row11_col8, #T_0a724_row13_col0, #T_0a724_row13_col2, #T_0a724_row13_col4, #T_0a724_row13_col6 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# #T_0a724_row0_col8, #T_0a724_row3_col10, #T_0a724_row9_col0, #T_0a724_row11_col2, #T_0a724_row11_col4, #T_0a724_row11_col6 {
#   background-color: #398649;
#   color: #f1f1f1;
# }
# #T_0a724_row1_col8 {
#   background-color: #82b28c;
#   color: #f1f1f1;
# }
# #T_0a724_row1_col10 {
#   background-color: #df5d67;
#   color: #f1f1f1;
# }
# #T_0a724_row2_col8 {
#   background-color: #6fa67a;
#   color: #f1f1f1;
# }
# #T_0a724_row2_col10 {
#   background-color: #e06770;
#   color: #f1f1f1;
# }
# #T_0a724_row3_col2, #T_0a724_row3_col6, #T_0a724_row5_col0, #T_0a724_row6_col2, #T_0a724_row6_col6, #T_0a724_row7_col2, #T_0a724_row7_col6, #T_0a724_row14_col0, #T_0a724_row14_col6, #T_0a724_row15_col6 {
#   background-color: #da3c48;
#   color: #f1f1f1;
# }
# #T_0a724_row3_col4, #T_0a724_row6_col4, #T_0a724_row7_col4, #T_0a724_row14_col2, #T_0a724_row14_col4, #T_0a724_row15_col4 {
#   background-color: #da3d49;
#   color: #f1f1f1;
# }
# #T_0a724_row3_col8 {
#   background-color: #6da679;
#   color: #f1f1f1;
# }
# #T_0a724_row4_col8 {
#   background-color: #71a87d;
#   color: #f1f1f1;
# }
# #T_0a724_row4_col10 {
#   background-color: #df636c;
#   color: #f1f1f1;
# }
# #T_0a724_row5_col2, #T_0a724_row15_col0, #T_0a724_row15_col2 {
#   background-color: #da3f4a;
#   color: #f1f1f1;
# }
# #T_0a724_row5_col4 {
#   background-color: #db434e;
#   color: #f1f1f1;
# }
# #T_0a724_row5_col6 {
#   background-color: #db404c;
#   color: #f1f1f1;
# }
# #T_0a724_row5_col8 {
#   background-color: #c2d9c7;
#   color: #000000;
# }
# #T_0a724_row5_col10 {
#   background-color: #c8ddcc;
#   color: #000000;
# }
# #T_0a724_row6_col8 {
#   background-color: #b8d3be;
#   color: #000000;
# }
# #T_0a724_row6_col10 {
#   background-color: #e79fa5;
#   color: #000000;
# }
# #T_0a724_row7_col8 {
#   background-color: #b4d1ba;
#   color: #000000;
# }
# #T_0a724_row7_col10 {
#   background-color: #ebbbbe;
#   color: #000000;
# }
# #T_0a724_row8_col0 {
#   background-color: #9ec3a5;
#   color: #000000;
# }
# #T_0a724_row8_col2 {
#   background-color: #9cc2a4;
#   color: #000000;
# }
# #T_0a724_row8_col4, #T_0a724_row8_col6 {
#   background-color: #a2c6a9;
#   color: #000000;
# }
# #T_0a724_row8_col8 {
#   background-color: #e58b91;
#   color: #f1f1f1;
# }
# #T_0a724_row8_col10 {
#   background-color: #dc4d58;
#   color: #f1f1f1;
# }
# #T_0a724_row9_col2 {
#   background-color: #3d894d;
#   color: #f1f1f1;
# }
# #T_0a724_row9_col4 {
#   background-color: #51955f;
#   color: #f1f1f1;
# }
# #T_0a724_row9_col6 {
#   background-color: #50945e;
#   color: #f1f1f1;
# }
# #T_0a724_row9_col8 {
#   background-color: #db424d;
#   color: #f1f1f1;
# }
# #T_0a724_row9_col10 {
#   background-color: #dd535d;
#   color: #f1f1f1;
# }
# #T_0a724_row10_col0, #T_0a724_row10_col2 {
#   background-color: #a6c8ad;
#   color: #000000;
# }
# #T_0a724_row10_col4, #T_0a724_row10_col6 {
#   background-color: #b0ceb6;
#   color: #000000;
# }
# #T_0a724_row10_col8 {
#   background-color: #e58c93;
#   color: #f1f1f1;
# }
# #T_0a724_row10_col10 {
#   background-color: #df616b;
#   color: #f1f1f1;
# }
# #T_0a724_row11_col0 {
#   background-color: #408a50;
#   color: #f1f1f1;
# }
# #T_0a724_row11_col10 {
#   background-color: #dd4f59;
#   color: #f1f1f1;
# }
# #T_0a724_row12_col0, #T_0a724_row15_col10 {
#   background-color: #629f6f;
#   color: #f1f1f1;
# }
# #T_0a724_row12_col2, #T_0a724_row15_col8 {
#   background-color: #63a070;
#   color: #f1f1f1;
# }
# #T_0a724_row12_col4, #T_0a724_row12_col6 {
#   background-color: #77ac82;
#   color: #f1f1f1;
# }
# #T_0a724_row12_col8 {
#   background-color: #de5b65;
#   color: #f1f1f1;
# }
# #T_0a724_row12_col10 {
#   background-color: #e37c84;
#   color: #f1f1f1;
# }
# #T_0a724_row13_col8 {
#   background-color: #8bb894;
#   color: #000000;
# }
# #T_0a724_row13_col10 {
#   background-color: #e16d75;
#   color: #f1f1f1;
# }
# #T_0a724_row14_col8 {
#   background-color: #a9cab0;
#   color: #000000;
# }
# #T_0a724_row14_col10 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# </style>
# <table id="T_0a724">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_0a724_level0_col0" class="col_heading level0 col0" colspan="2">MAP</th>
#       <th id="T_0a724_level0_col2" class="col_heading level0 col2" colspan="2">NDCG</th>
#       <th id="T_0a724_level0_col4" class="col_heading level0 col4" colspan="2">precision</th>
#       <th id="T_0a724_level0_col6" class="col_heading level0 col6" colspan="2">recall</th>
#       <th id="T_0a724_level0_col8" class="col_heading level0 col8" colspan="2">novelty</th>
#       <th id="T_0a724_level0_col10" class="col_heading level0 col10" colspan="2">serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >At</th>
#       <th id="T_0a724_level1_col0" class="col_heading level1 col0" colspan="2">10</th>
#       <th id="T_0a724_level1_col2" class="col_heading level1 col2" colspan="2">10</th>
#       <th id="T_0a724_level1_col4" class="col_heading level1 col4" colspan="2">10</th>
#       <th id="T_0a724_level1_col6" class="col_heading level1 col6" colspan="2">10</th>
#       <th id="T_0a724_level1_col8" class="col_heading level1 col8" colspan="2">10</th>
#       <th id="T_0a724_level1_col10" class="col_heading level1 col10" colspan="2">10</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Stat</th>
#       <th id="T_0a724_level2_col0" class="col_heading level2 col0" >mean</th>
#       <th id="T_0a724_level2_col1" class="col_heading level2 col1" >std</th>
#       <th id="T_0a724_level2_col2" class="col_heading level2 col2" >mean</th>
#       <th id="T_0a724_level2_col3" class="col_heading level2 col3" >std</th>
#       <th id="T_0a724_level2_col4" class="col_heading level2 col4" >mean</th>
#       <th id="T_0a724_level2_col5" class="col_heading level2 col5" >std</th>
#       <th id="T_0a724_level2_col6" class="col_heading level2 col6" >mean</th>
#       <th id="T_0a724_level2_col7" class="col_heading level2 col7" >std</th>
#       <th id="T_0a724_level2_col8" class="col_heading level2 col8" >mean</th>
#       <th id="T_0a724_level2_col9" class="col_heading level2 col9" >std</th>
#       <th id="T_0a724_level2_col10" class="col_heading level2 col10" >mean</th>
#       <th id="T_0a724_level2_col11" class="col_heading level2 col11" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a724_level0_row0" class="row_heading level0 row0" >lfm__16_bpr_0.01_0.2_0.2</th>
#       <td id="T_0a724_row0_col0" class="data row0 col0" >0.000004</td>
#       <td id="T_0a724_row0_col1" class="data row0 col1" >0.000006</td>
#       <td id="T_0a724_row0_col2" class="data row0 col2" >0.000003</td>
#       <td id="T_0a724_row0_col3" class="data row0 col3" >0.000002</td>
#       <td id="T_0a724_row0_col4" class="data row0 col4" >0.000004</td>
#       <td id="T_0a724_row0_col5" class="data row0 col5" >0.000003</td>
#       <td id="T_0a724_row0_col6" class="data row0 col6" >0.000012</td>
#       <td id="T_0a724_row0_col7" class="data row0 col7" >0.000009</td>
#       <td id="T_0a724_row0_col8" class="data row0 col8" >17.906417</td>
#       <td id="T_0a724_row0_col9" class="data row0 col9" >0.859115</td>
#       <td id="T_0a724_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_0a724
# CPU times: user 5h 39min 2s, sys: 48min 50s, total: 6h 27min 53s
# Wall time: 29min 32s

# %%
# %%time
result_data_lfm1 = calculate_metrics(
    models_lfm_wrapper_list[1], kion_data, metrics, cv_7d, k_recos=k_recos, style=True, verbose=1
)
display(result_data_lfm1)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.2 | Fold: 0=======================================================
# Fit time: 6.42 sec.
# Recommend time: 6.63 sec.
# Metrics time: 1.92 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.5 | Fold: 0=======================================================
# Fit time: 12.05 sec.
# Recommend time: 6.54 sec.
# Metrics time: 1.79 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.2 | Fold: 0=======================================================
# Fit time: 13.84 sec.
# Recommend time: 8.95 sec.
# Metrics time: 1.86 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.5 | Fold: 0=======================================================
# Fit time: 15.11 sec.
# Recommend time: 8.53 sec.
# Metrics time: 1.98 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.2 | Fold: 0=======================================================
# Fit time: 31.64 sec.
# Recommend time: 6.7 sec.
# Metrics time: 1.71 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.5 | Fold: 0=======================================================
# Fit time: 89.44 sec.
# Recommend time: 8.41 sec.
# Metrics time: 1.88 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.2 | Fold: 0=======================================================
# Fit time: 90.4 sec.
# Recommend time: 7.78 sec.
# Metrics time: 1.81 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.5 | Fold: 0=======================================================
# Fit time: 92.52 sec.
# Recommend time: 7.94 sec.
# Metrics time: 1.89 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.2 | Fold: 0=======================================================
# Fit time: 4.9 sec.
# Recommend time: 7.23 sec.
# Metrics time: 1.77 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.5 | Fold: 0=======================================================
# Fit time: 17.13 sec.
# Recommend time: 7.97 sec.
# Metrics time: 1.95 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.2 | Fold: 0=======================================================
# Fit time: 21.56 sec.
# Recommend time: 7.36 sec.
# Metrics time: 2.0 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.5 | Fold: 0=======================================================
# Fit time: 14.5 sec.
# Recommend time: 7.09 sec.
# Metrics time: 1.96 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.2 | Fold: 0=======================================================
# Fit time: 34.1 sec.
# Recommend time: 8.02 sec.
# Metrics time: 2.16 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.5 | Fold: 0=======================================================
# Fit time: 115.78 sec.
# Recommend time: 8.35 sec.
# Metrics time: 2.19 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.2 | Fold: 0=======================================================
# Fit time: 127.49 sec.
# Recommend time: 7.94 sec.
# Metrics time: 1.72 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.5 | Fold: 0=======================================================
# Fit time: 107.8 sec.
# Recommend time: 8.63 sec.
# Metrics time: 1.88 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.2 | Fold: 1=======================================================
# Fit time: 7.28 sec.
# Recommend time: 9.27 sec.
# Metrics time: 2.1 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.5 | Fold: 1=======================================================
# Fit time: 14.92 sec.
# Recommend time: 7.76 sec.
# Metrics time: 1.84 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.2 | Fold: 1=======================================================
# Fit time: 15.55 sec.
# Recommend time: 8.63 sec.
# Metrics time: 2.13 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.5 | Fold: 1=======================================================
# Fit time: 17.68 sec.
# Recommend time: 9.17 sec.
# Metrics time: 2.16 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.2 | Fold: 1=======================================================
# Fit time: 37.69 sec.
# Recommend time: 8.99 sec.
# Metrics time: 2.16 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.5 | Fold: 1=======================================================
# Fit time: 108.01 sec.
# Recommend time: 9.01 sec.
# Metrics time: 2.07 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.2 | Fold: 1=======================================================
# Fit time: 108.89 sec.
# Recommend time: 8.84 sec.
# Metrics time: 2.01 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.5 | Fold: 1=======================================================
# Fit time: 106.49 sec.
# Recommend time: 7.68 sec.
# Metrics time: 2.18 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.2 | Fold: 1=======================================================
# Fit time: 5.27 sec.
# Recommend time: 8.16 sec.
# Metrics time: 1.86 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.5 | Fold: 1=======================================================
# Fit time: 20.12 sec.
# Recommend time: 7.85 sec.
# Metrics time: 2.06 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.2 | Fold: 1=======================================================
# Fit time: 25.08 sec.
# Recommend time: 9.33 sec.
# Metrics time: 1.99 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.5 | Fold: 1=======================================================
# Fit time: 16.18 sec.
# Recommend time: 7.26 sec.
# Metrics time: 1.84 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.2 | Fold: 1=======================================================
# Fit time: 38.87 sec.
# Recommend time: 8.05 sec.
# Metrics time: 1.95 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.5 | Fold: 1=======================================================
# Fit time: 126.88 sec.
# Recommend time: 6.8 sec.
# Metrics time: 1.74 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.2 | Fold: 1=======================================================
# Fit time: 142.57 sec.
# Recommend time: 8.15 sec.
# Metrics time: 1.83 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.5 | Fold: 1=======================================================
# Fit time: 119.19 sec.
# Recommend time: 8.35 sec.
# Metrics time: 1.98 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.2 | Fold: 2=======================================================
# Fit time: 8.38 sec.
# Recommend time: 9.31 sec.
# Metrics time: 2.1 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.2_0.5 | Fold: 2=======================================================
# Fit time: 17.48 sec.
# Recommend time: 8.66 sec.
# Metrics time: 2.07 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.2 | Fold: 2=======================================================
# Fit time: 17.9 sec.
# Recommend time: 10.01 sec.
# Metrics time: 2.28 sec.
# =======================================================|| Model: lfm__32_bpr_0.01_0.5_0.5 | Fold: 2=======================================================
# Fit time: 19.16 sec.
# Recommend time: 8.51 sec.
# Metrics time: 2.07 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.2 | Fold: 2=======================================================
# Fit time: 41.71 sec.
# Recommend time: 8.26 sec.
# Metrics time: 1.98 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.2_0.5 | Fold: 2=======================================================
# Fit time: 123.49 sec.
# Recommend time: 9.49 sec.
# Metrics time: 2.26 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.2 | Fold: 2=======================================================
# Fit time: 127.35 sec.
# Recommend time: 8.24 sec.
# Metrics time: 2.28 sec.
# =======================================================|| Model: lfm__32_bpr_0.05_0.5_0.5 | Fold: 2=======================================================
# Fit time: 131.19 sec.
# Recommend time: 8.25 sec.
# Metrics time: 2.27 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.2 | Fold: 2=======================================================
# Fit time: 6.75 sec.
# Recommend time: 8.12 sec.
# Metrics time: 2.33 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.2_0.5 | Fold: 2=======================================================
# Fit time: 24.37 sec.
# Recommend time: 9.14 sec.
# Metrics time: 2.31 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.2 | Fold: 2=======================================================
# Fit time: 29.23 sec.
# Recommend time: 7.67 sec.
# Metrics time: 2.0 sec.
# =======================================================|| Model: lfm__32_warp_0.01_0.5_0.5 | Fold: 2=======================================================
# Fit time: 19.18 sec.
# Recommend time: 7.51 sec.
# Metrics time: 2.02 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.2 | Fold: 2=======================================================
# Fit time: 43.39 sec.
# Recommend time: 7.53 sec.
# Metrics time: 1.95 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.2_0.5 | Fold: 2=======================================================
# Fit time: 141.62 sec.
# Recommend time: 7.71 sec.
# Metrics time: 2.07 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.2 | Fold: 2=======================================================
# Fit time: 162.43 sec.
# Recommend time: 9.8 sec.
# Metrics time: 2.13 sec.
# =======================================================|| Model: lfm__32_warp_0.05_0.5_0.5 | Fold: 2=======================================================
# Fit time: 132.37 sec.
# Recommend time: 7.65 sec.
# Metrics time: 1.98 sec.
# <style type="text/css">
# #T_0d547_row0_col0, #T_0d547_row0_col2, #T_0d547_row0_col6, #T_0d547_row1_col0, #T_0d547_row1_col2, #T_0d547_row1_col4, #T_0d547_row1_col6, #T_0d547_row2_col0, #T_0d547_row2_col2, #T_0d547_row2_col4, #T_0d547_row2_col6, #T_0d547_row3_col0, #T_0d547_row3_col2, #T_0d547_row3_col4, #T_0d547_row3_col6, #T_0d547_row4_col0, #T_0d547_row4_col2, #T_0d547_row4_col4, #T_0d547_row4_col6, #T_0d547_row5_col0, #T_0d547_row5_col2, #T_0d547_row5_col4, #T_0d547_row5_col6, #T_0d547_row8_col8, #T_0d547_row8_col10, #T_0d547_row13_col0, #T_0d547_row13_col2, #T_0d547_row13_col4, #T_0d547_row13_col6 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# #T_0d547_row0_col4, #T_0d547_row7_col0 {
#   background-color: #da3c48;
#   color: #f1f1f1;
# }
# #T_0d547_row0_col8 {
#   background-color: #438c52;
#   color: #f1f1f1;
# }
# #T_0d547_row0_col10 {
#   background-color: #e06b74;
#   color: #f1f1f1;
# }
# #T_0d547_row1_col8, #T_0d547_row9_col0 {
#   background-color: #478f56;
#   color: #f1f1f1;
# }
# #T_0d547_row1_col10 {
#   background-color: #df5d67;
#   color: #f1f1f1;
# }
# #T_0d547_row2_col8 {
#   background-color: #73a97e;
#   color: #f1f1f1;
# }
# #T_0d547_row2_col10 {
#   background-color: #edc9cb;
#   color: #000000;
# }
# #T_0d547_row3_col8, #T_0d547_row6_col10, #T_0d547_row8_col0, #T_0d547_row8_col2, #T_0d547_row8_col4, #T_0d547_row8_col6 {
#   background-color: #398649;
#   color: #f1f1f1;
# }
# #T_0d547_row3_col10 {
#   background-color: #e9abaf;
#   color: #000000;
# }
# #T_0d547_row4_col8 {
#   background-color: #7eb088;
#   color: #f1f1f1;
# }
# #T_0d547_row4_col10 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_0d547_row5_col8 {
#   background-color: #89b793;
#   color: #000000;
# }
# #T_0d547_row5_col10, #T_0d547_row11_col2 {
#   background-color: #dce9de;
#   color: #000000;
# }
# #T_0d547_row6_col0, #T_0d547_row7_col2 {
#   background-color: #da3d49;
#   color: #f1f1f1;
# }
# #T_0d547_row6_col2 {
#   background-color: #db424d;
#   color: #f1f1f1;
# }
# #T_0d547_row6_col4, #T_0d547_row9_col8 {
#   background-color: #db4651;
#   color: #f1f1f1;
# }
# #T_0d547_row6_col6, #T_0d547_row15_col2 {
#   background-color: #db434e;
#   color: #f1f1f1;
# }
# #T_0d547_row6_col8 {
#   background-color: #a8c9ae;
#   color: #000000;
# }
# #T_0d547_row7_col4, #T_0d547_row7_col6, #T_0d547_row15_col0 {
#   background-color: #da3f4a;
#   color: #f1f1f1;
# }
# #T_0d547_row7_col8 {
#   background-color: #a1c5a8;
#   color: #000000;
# }
# #T_0d547_row7_col10 {
#   background-color: #cee0d1;
#   color: #000000;
# }
# #T_0d547_row9_col2 {
#   background-color: #4d925b;
#   color: #f1f1f1;
# }
# #T_0d547_row9_col4 {
#   background-color: #559763;
#   color: #f1f1f1;
# }
# #T_0d547_row9_col6 {
#   background-color: #579864;
#   color: #f1f1f1;
# }
# #T_0d547_row9_col10, #T_0d547_row10_col8 {
#   background-color: #dd505a;
#   color: #f1f1f1;
# }
# #T_0d547_row10_col0, #T_0d547_row14_col10 {
#   background-color: #498f58;
#   color: #f1f1f1;
# }
# #T_0d547_row10_col2 {
#   background-color: #549662;
#   color: #f1f1f1;
# }
# #T_0d547_row10_col4 {
#   background-color: #68a274;
#   color: #f1f1f1;
# }
# #T_0d547_row10_col6 {
#   background-color: #69a375;
#   color: #f1f1f1;
# }
# #T_0d547_row10_col10 {
#   background-color: #e1727b;
#   color: #f1f1f1;
# }
# #T_0d547_row11_col0 {
#   background-color: #d3e3d6;
#   color: #000000;
# }
# #T_0d547_row11_col4 {
#   background-color: #ebf2ec;
#   color: #000000;
# }
# #T_0d547_row11_col6 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_0d547_row11_col8, #T_0d547_row13_col10 {
#   background-color: #edcacd;
#   color: #000000;
# }
# #T_0d547_row11_col10 {
#   background-color: #de5b65;
#   color: #f1f1f1;
# }
# #T_0d547_row12_col0 {
#   background-color: #78ac83;
#   color: #f1f1f1;
# }
# #T_0d547_row12_col2 {
#   background-color: #88b691;
#   color: #f1f1f1;
# }
# #T_0d547_row12_col4 {
#   background-color: #9ec3a5;
#   color: #000000;
# }
# #T_0d547_row12_col6 {
#   background-color: #9cc2a4;
#   color: #000000;
# }
# #T_0d547_row12_col8 {
#   background-color: #e58b91;
#   color: #f1f1f1;
# }
# #T_0d547_row12_col10 {
#   background-color: #e79ca2;
#   color: #000000;
# }
# #T_0d547_row13_col8 {
#   background-color: #50945e;
#   color: #f1f1f1;
# }
# #T_0d547_row14_col0 {
#   background-color: #dd4f59;
#   color: #f1f1f1;
# }
# #T_0d547_row14_col2 {
#   background-color: #de5963;
#   color: #f1f1f1;
# }
# #T_0d547_row14_col4 {
#   background-color: #df646d;
#   color: #f1f1f1;
# }
# #T_0d547_row14_col6 {
#   background-color: #e0656f;
#   color: #f1f1f1;
# }
# #T_0d547_row14_col8 {
#   background-color: #9ac0a2;
#   color: #000000;
# }
# #T_0d547_row15_col4 {
#   background-color: #dc4954;
#   color: #f1f1f1;
# }
# #T_0d547_row15_col6 {
#   background-color: #dc4752;
#   color: #f1f1f1;
# }
# #T_0d547_row15_col8 {
#   background-color: #74aa7f;
#   color: #f1f1f1;
# }
# #T_0d547_row15_col10 {
#   background-color: #e16f78;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d547">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_0d547_level0_col0" class="col_heading level0 col0" colspan="2">MAP</th>
#       <th id="T_0d547_level0_col2" class="col_heading level0 col2" colspan="2">NDCG</th>
#       <th id="T_0d547_level0_col4" class="col_heading level0 col4" colspan="2">precision</th>
#       <th id="T_0d547_level0_col6" class="col_heading level0 col6" colspan="2">recall</th>
#       <th id="T_0d547_level0_col8" class="col_heading level0 col8" colspan="2">novelty</th>
#       <th id="T_0d547_level0_col10" class="col_heading level0 col10" colspan="2">serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >At</th>
#       <th id="T_0d547_level1_col0" class="col_heading level1 col0" colspan="2">10</th>
#       <th id="T_0d547_level1_col2" class="col_heading level1 col2" colspan="2">10</th>
#       <th id="T_0d547_level1_col4" class="col_heading level1 col4" colspan="2">10</th>
#       <th id="T_0d547_level1_col6" class="col_heading level1 col6" colspan="2">10</th>
#       <th id="T_0d547_level1_col8" class="col_heading level1 col8" colspan="2">10</th>
#       <th id="T_0d547_level1_col10" class="col_heading level1 col10" colspan="2">10</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Stat</th>
#       <th id="T_0d547_level2_col0" class="col_heading level2 col0" >mean</th>
#       <th id="T_0d547_level2_col1" class="col_heading level2 col1" >std</th>
#       <th id="T_0d547_level2_col2" class="col_heading level2 col2" >mean</th>
#       <th id="T_0d547_level2_col3" class="col_heading level2 col3" >std</th>
#       <th id="T_0d547_level2_col4" class="col_heading level2 col4" >mean</th>
#       <th id="T_0d547_level2_col5" class="col_heading level2 col5" >std</th>
#       <th id="T_0d547_level2_col6" class="col_heading level2 col6" >mean</th>
#       <th id="T_0d547_level2_col7" class="col_heading level2 col7" >std</th>
#       <th id="T_0d547_level2_col8" class="col_heading level2 col8" >mean</th>
#       <th id="T_0d547_level2_col9" class="col_heading level2 col9" >std</th>
#       <th id="T_0d547_level2_col10" class="col_heading level2 col10" >mean</th>
#       <th id="T_0d547_level2_col11" class="col_heading level2 col11" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d547_level0_row0" class="row_heading level0 row0" >lfm__32_bpr_0.01_0.2_0.2</th>
#       <td id="T_0d547_row0_col0" class="data row0 col0" >0.000100</td>
#       <td id="T_0d547_row0_col1" class="data row0 col1" >0.000169</td>
#       <td id="T_0d547_row0_col2" class="data row0 col2" >0.000166</td>
#       <td id="T_0d547_row0_col3" class="data row0 col3" >0.000280</td>
#       <td id="T_0d547_row0_col4" class="data row0 col4" >0.000216</td>
#       <td id="T_0d547_row0_col5" class="data row0 col5" >0.000364</td>
#       <td id="T_0d547_row0_co
# CPU times: user 9h 8min 11s, sys: 48min 13s, total: 9h 56min 24s
# Wall time: 54min 3s

# %% [markdown]
# ### Выводы
#
# 1. ALS определенно хуже LFM (0.01-0.02 против 0.07 у лучшего в lfm)
# 2. ALS:
#     * Лучше работает на количестве факторов поменьше (16 лучше 32);
#     * Лучше работает на `is_fitting_features=False` (то есть дефолтные фичи лучше);
# 3. LFM:
#     * `LOSS` `bpr` работает хуже `warp`;
#     *  `LEARNING_RATE`: в данных экспериментах лучше себя продемонстрировал 0.01 (против 0.05)
#     *  `USER_ALPHA` и `ITEM_ALPHA`: сначала пробовал по нулям еще, там вообще все плохо. Если смотреть комбинации `0.2` и `0.5` (как делали в эксперименте), то по всей видимости все очень сильно зависит от `LEARNING_RATE` и  `N_FACTORS`, но в целом оба себя неплохо показали.

# %% [markdown]
# ### Лучший

# %% [markdown]
# Давайте проверим лучший: `lfm__32_warp_0.01_0.2_0.2`.

# %%
model = deepcopy(models_lfm_wrapper_list[1]["lfm__32_warp_0.01_0.2_0.2"])
model.fit(dataset_for_train)

# %%
# %%time
visualize(model=model, dataset=kion_data, user_list=users_list, item_data=item_data, k_recos=10, display=display)
# Out:
# Visual report
# ----------------------------------------------------------
# User: 79446
# Already watched films amount: 33
# Display last 10 watched:
#     item_id   datetime  weight  watched_pct  item_id_x  \
# 15      512 2021-08-15  3303.0         58.0        512
# 32     1896 2021-08-01  3720.0         57.0       1896
# 19     7597 2021-08-01  5752.0        100.0       7597
# 9     16415 2021-07-28  6847.0        100.0      16415
# 7      4880 2021-07-25  2634.0          9.0       4880
# 14    12356 2021-07-18  4071.0         77.0      12356
# 30     9194 2021-07-17  6760.0         95.0       9194
# 18     9728 2021-07-17    52.0          1.0       9728
# 5     10240 2021-07-16  6126.0        100.0      10240
# 25    10464 2021-07-13     8.0          0.0      10464
#
#                         title                        genres  item_id_y
# 15             Рядовой Чээрин                       военные      10230
# 32                    Явление                драмы, военные        674
# 19    Препод: История Галатеи     драмы, триллеры, криминал       1717
# 9                       Весна  фантастика, ужасы, мелодрамы        624
# 7                       Афера                       комедии      55043
# 14                  13 грехов               ужасы, триллеры       6874
# 30  Роберт — король Шотландии                       боевики       8030
# 18          Гнев человеческий             боевики, триллеры     132865
# 5                Клаустрофобы                      триллеры       4336
# 25               Вирус страха               драмы, триллеры      10375
# Recommended films amount: 10
# (Amount of all films: 15706)
# Display first 10 recommendations:
#    item_id         score  rank  item_id_x                         title  \
# 0    10440  5.590878e-07     1      10440                   Хрустальный
# 1    15297  5.469008e-07     2      15297               Клиника счастья
# 2     4151  3.630557e-07     3       4151        Секреты семейной жизни
# 3     3734  3.479939e-07     4       3734  Прабабушка легкого поведения
# 4     2657  3.332943e-07     5       2657                    Подслушано
# 5    12192  2.642404e-07     6      12192                  Фемида видит
# 6     8636  2.553672e-07     7       8636                    Белый снег
# 7     7571  2.406811e-07     8       7571                     100% волк
# 8     4740  2.354064e-07     9       4740            Сахаров. Две жизни
# 9      142  2.326558e-07    10        142                          Маша
#
#                                               genres  item_id_y
# 0                                триллеры, детективы     202457
# 1                                   драмы, мелодрамы     193123
# 2                                            комедии      91167
# 3                                            комедии      74803
# 4                                    драмы, триллеры      68581
# 5                          драмы, детективы, комедии      38242
# 6                                       драмы, спорт      35631
# 7  мультфильм, приключения, семейное, фэнтези, ко...      28372
# 8                                     документальное      34325
# 9                                    драмы, триллеры      45367
# ----------------------------------------------------------
# User: 1074610
# Already watched films amount: 1
# Display last 10 watched:
#    item_id   datetime  weight  watched_pct  item_id_x            title  \
# 0    15297 2021-07-28  1402.0         13.0      15297  Клиника счастья
#
#              genres  item_id_y
# 0  драмы, мелодрамы     193123
# Recommended films amount: 10
# (Amount of all films: 15706)
# Display first 10 recommendations:
#    item_id         score  rank  item_id_x                         title  \
# 0    10440  5.590878e-07     1      10440                   Хрустальный
# 1    13865  4.105240e-07     2      13865                      Девятаев
# 2     9728  4.057316e-07     3       9728             Гнев человеческий
# 3     4151  3.630557e-07     4       4151        Секреты семейной жизни
# 4     3734  3.479939e-07     5       3734  Прабабушка легкого поведения
# 5     2657  3.332943e-07     6       2657                    Подслушано
# 6    12192  2.642404e-07     7      12192                  Фемида видит
# 7     4880  2.594152e-07     8       4880                         Афера
# 8     8636  2.553672e-07     9       8636                    Белый снег
# 9     7571  2.406811e-07    10       7571                     100% волк
#
#                                               genres  item_id_y
# 0                                триллеры, детективы     202457
# 1                        драмы, военные, приключения     122119
# 2                                  боевики, триллеры     132865
# 3                                            комедии      91167
# 4                                            комедии      74803
# 5                                    драмы, триллеры      68581
# 6                          драмы, детективы, комедии      38242
# 7                                            комедии      55043
# 8                                       драмы, спорт      35631
# 9  мультфильм, приключения, семейное, фэнтези, ко...      28372
# CPU times: user 1.01 s, sys: 1.03 s, total: 2.04 s
# Wall time: 821 ms

# %%
# %%timeit
model.recommend(users=[10], dataset=dataset_for_train, k=10, filter_viewed=True)
# Out:
# 303 ms ± 5.88 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### ANN
#
# Чтобы улучшить скорость, попробуем приближенный метод поиска соседей: ANN.

# %%
# %%time
user_vectors, item_vectors = model.get_vectors(dataset_for_train)
ann_lfm = UserToItemAnnRecommender(
    user_vectors=user_vectors,
    item_vectors=item_vectors,
    user_id_map=dataset.user_id_map,
    item_id_map=dataset.item_id_map,
)
ann_lfm.fit()
# Out:
# CPU times: user 16min 29s, sys: 1.45 s, total: 16min 31s
# Wall time: 1min 13s

# %%
# %%timeit

ann_lfm.get_item_list_for_user(10, top_n=10).tolist()
# Out:
# 20.1 ms ± 618 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Скорость лучше в разы, ее и будем использовать в проде.

# %% [markdown]
# # Сохраним модель

# %%
import pickle

# %%
name_lfm = "../models/pickle_data/ann_lfm.pickle"
pickle.dump(ann_lfm, open(name_lfm, "wb"))

# %% [markdown]
# Также сохраним модель популярного отдельно (чтобы ее подгрузить, и взять список популярного).

# %%
name_popular = "../models/pickle_data/popular.pickle"
pickle.dump(model_popular, open(name_popular, "wb"))

# %% [markdown]
# # Проверка работоспособности

# %% [markdown]
# Подгружаем данные, и уже просмотренные юзером фильмы.

# %%
kion_data = read_kion_dataset(fast_check=1)
interactions = kion_data["interactions"]
data_for_predict = Dataset.construct(interactions.df)

watched = dict(interactions.df[["user_id", "item_id"]].groupby("user_id")["item_id"].agg(list))
watched[0]
# Out:
# [7102, 14359, 15297, 6006, 9728, 12192]

# %% [markdown]
# Запоминаем, сколько всего фильмов

# %%
max_k = len(kion_data["items"]["item_id"].unique())

# %% [markdown]
# Подгружаем список популярного, в порядке рекомендаций, после этого этот список можно будет использовать, чтобы дополнять холодных юзеров, а также, если не хватает.

# %%
name_popular = "../models/pickle_data/popular.pickle"
loaded_popular = pickle.load(open(name_popular, "rb"))

sample_popular_user = data_for_predict.user_id_map.external_ids[0]
popular_list = list(
    loaded_popular.recommend(dataset=data_for_predict, users=[0], k=max_k, filter_viewed=False)["item_id"]
)
popular_list[:10], len(popular_list)
# Out:
# ([10440, 15297, 9728, 13865, 4151, 3734, 2657, 4880, 142, 6809], 15706)

# %%
name_lfm = "../models/pickle_data/ann_lfm.pickle"
loaded_lfm = pickle.load(open(name_lfm, "rb"))

# %% [markdown]
# Все, что делали выше -- происходит 1 раз при старте сервиса, а дальше просто предсказания:
#
# - вызываем модель
# - фильтруем, если уже просмотрено
# - добавляем популярное при необходимости (опять же, проверяя, что не просмотрено еще).

# %%
# %%timeit

user_id = 10
k = 10

final_prediction = []
if user_id in watched:
    cur_watched = watched[user_id]
    final_prediction = loaded_lfm.get_item_list_for_user(user_id, top_n=k).tolist()
    # check watched
    final_prediction = [film for film in final_prediction if film not in cur_watched]
    # append popular, if not enough
    for item in popular_list:
        if len(final_prediction) >= k:
            break
        if item not in cur_watched and item not in final_prediction:
            final_prediction.append(item)
else:
    final_prediction = popular_list[:k]
# Out:
# 27.7 ms ± 6.28 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
